# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt,seaborn as sns, sklearn

# %%
df = pd.read_csv(r'C:\Users\user\Downloads\groupbyExcercise - groupbyExcercise.csv')
df
# Out:
#     Unnamed: 0        Date Product  Revenue  Quantity
# 0            0  2023-01-01       A      221         3
# 1            1  2023-01-01       B      111         8
# 2            2  2023-01-02       B      171        11
# 3            3  2023-01-02       A      141        15
# 4            4  2023-02-01       A       75         4
# 5            5  2023-02-01       B       90        12
# 6            6  2023-02-02       A       96        17
# 7            7  2023-02-02       B      170        10
# 8            8  2023-03-01       B      200        19
# 9            9  2023-03-01       A      120        10
# 10          10  2023-03-02       A      121        12
# 11          11  2023-03-02       B      150         5

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      12 non-null     object
#  1   Product   12 non-null     object
#  2   Revenue   12 non-null     int64
#  3   Quantity  12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 516.0+ bytes

# %% [markdown]
# ## 1. Arrange DataFrame df, focusing on distinct product categories. Explore the data to reveal:
# ### Overall revenue insights

# %%
df.groupby(['Product'])['Revenue'].sum()
# Out:
# Product
# A    774
# B    892
# Name: Revenue, dtype: int64

# %% [markdown]
# ### Average revenue patterns

# %%
df.groupby(['Product'])['Revenue'].mean()
# Out:
# Product
# A    129.000000
# B    148.666667
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Peak quantity sold observations

# %%
df.groupby(['Product'])['Quantity'].max()
# Out:
# Product
# A    17
# B    19
# Name: Quantity, dtype: int64

# %% [markdown]
# ### Minimum quantity sold occurrences

# %%
df.groupby(['Product'])['Quantity'].min()
# Out:
# Product
# A    3
# B    5
# Name: Quantity, dtype: int64

# %% [markdown]
# ## 2. Aggregate DataFrame df by extracting the month and year from the 'Date' column. Calculate the collective revenue for each unique combination of month and year.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year

df
# Out:
#          Date Product  Revenue  Quantity  Year
# 0  2023-01-01       A      221         3  2023
# 1  2023-01-01       B      111         8  2023
# 2  2023-01-02       B      171        11  2023
# 3  2023-01-02       A      141        15  2023
# 4  2023-02-01       A       75         4  2023
# 5  2023-02-01       B       90        12  2023
# 6  2023-02-02       A       96        17  2023
# 7  2023-02-02       B      170        10  2023
# 8  2023-03-01       B      200        19  2023
# 9  2023-03-01       A      120        10  2023
# 10 2023-03-02       A      121        12  2023
# 11 2023-03-02       B      150         5  2023

# %%
df['Month'] = df['Date'].dt.month

df
# Out:
#          Date Product  Revenue  Quantity  Year  Month
# 0  2023-01-01       A      221         3  2023      1
# 1  2023-01-01       B      111         8  2023      1
# 2  2023-01-02       B      171        11  2023      1
# 3  2023-01-02       A      141        15  2023      1
# 4  2023-02-01       A       75         4  2023      2
# 5  2023-02-01       B       90        12  2023      2
# 6  2023-02-02       A       96        17  2023      2
# 7  2023-02-02       B      170        10  2023      2
# 8  2023-03-01       B      200        19  2023      3
# 9  2023-03-01       A      120        10  2023      3
# 10 2023-03-02       A      121        12  2023      3
# 11 2023-03-02       B      150         5  2023      3

# %%
df.groupby(['Year', 'Month'])['Revenue'].sum()
# Out:
# Year  Month
# 2023  1        644
#       2        431
#       3        591
# Name: Revenue, dtype: int64

# %% [markdown]
# ## 3. Group the DataFrame df by the 'Date' column and find the date with the highest total revenue and the date with the highest total quantity sold.

# %%
# the date with the highest total revenue

x = df.groupby(['Date'])['Revenue'].sum()

h = x.idxmax()

print('Date with the highest total revenue : ',h)
# Out:
# Date with the highest total revenue :  2023-01-01 00:00:00

# %%
# the date with the highest total quantity sold

y = df.groupby(['Date'])['Quantity'].sum()

p = y.idxmax()

print('Date with the highest total quantity sold : ',p)
# Out:
# Date with the highest total quantity sold :  2023-03-01 00:00:00

# %% [markdown]
# ## 4. Group the DataFrame df by the Date and find products that have a total quantity sold greater than 10 and less than 15 .

# %%
a = df.groupby(['Date','Product'])['Quantity'].sum()

b = a[(a > 10) & (a < 15)]
b
# Out:
# Date        Product
# 2023-01-02  B          11
# 2023-02-01  B          12
# 2023-03-02  A          12
# Name: Quantity, dtype: int64

# %% [markdown]
# ## 5. Group the DataFrame df by the 'Product' column and add a new column 'Revenue Percentage' that shows the percentage of each product's revenue relative to the total revenue for that product.

# %%
df['Total Product Revenue'] = df.groupby(['Product'])['Revenue'].transform('sum')

df
# Out:
#          Date Product  Revenue  Quantity  Year  Month  Total Product Revenue
# 0  2023-01-01       A      221         3  2023      1                    774
# 1  2023-01-01       B      111         8  2023      1                    892
# 2  2023-01-02       B      171        11  2023      1                    892
# 3  2023-01-02       A      141        15  2023      1                    774
# 4  2023-02-01       A       75         4  2023      2                    774
# 5  2023-02-01       B       90        12  2023      2                    892
# 6  2023-02-02       A       96        17  2023      2                    774
# 7  2023-02-02       B      170        10  2023      2                    892
# 8  2023-03-01       B      200        19  2023      3                    892
# 9  2023-03-01       A      120        10  2023      3                    774
# 10 2023-03-02       A      121        12  2023      3                    774
# 11 2023-03-02       B      150         5  2023      3                    892

# %%
df['Revenue Percentage'] = (df['Revenue'] / df['Total Product Revenue']) * 100

df
# Out:
#          Date Product  Revenue  Quantity  Year  Month  Total Product Revenue  \
# 0  2023-01-01       A      221         3  2023      1                    774
# 1  2023-01-01       B      111         8  2023      1                    892
# 2  2023-01-02       B      171        11  2023      1                    892
# 3  2023-01-02       A      141        15  2023      1                    774
# 4  2023-02-01       A       75         4  2023      2                    774
# 5  2023-02-01       B       90        12  2023      2                    892
# 6  2023-02-02       A       96        17  2023      2                    774
# 7  2023-02-02       B      170        10  2023      2                    892
# 8  2023-03-01       B      200        19  2023      3                    892
# 9  2023-03-01       A      120        10  2023      3                    774
# 10 2023-03-02       A      121        12  2023      3                    774
# 11 2023-03-02       B      150         5  2023      3                    892
#
#     Revenue Percentage
# 0            28.552972
# 1            12.443946
# 2            19.170404
# 3            18.217054
# 4             9.689922
# 5            10.089686
# 6            12.403101
# 7            19.058296
# 8            22.421525
# 9            15.503876
# 10           15.633075
# 11           16.816143
